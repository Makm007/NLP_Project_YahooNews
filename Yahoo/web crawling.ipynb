# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import json
from datetime import datetime, timedelta

# Setup Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run in the background
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to generate dates for January 2025
def get_january_2025_dates():
    start_date = datetime(2025, 1, 1)
    end_date = datetime(2025, 1, 7)
    dates = []
    current_date = start_date
    while current_date <= end_date:
        dates.append(current_date.strftime("%Y_%m_%d"))
        current_date += timedelta(days=1)
    return dates

# Dictionary to store the count of news links per day
daily_counts = {}

# Get all dates for January 2025
january_dates = get_january_2025_dates()

# Counter for total links across all days
total_links = 0

# Iterate through each date
for date in january_dates:
    print(f"Scraping sitemap for date: {date}")
    current_url = f"https://finance.yahoo.com/sitemap/{date}"

    # List to store news links for this date
    news_links = []

    while True:
        # Load the page
        driver.get(current_url)
        time.sleep(5)  # Wait for JavaScript to load

        # Get page source and parse with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Find the sitemap content div
        sitemap_div = soup.find("div", {"id": "module-sitemapcontent"})

        # Scrape news links from the current page
        if sitemap_div:
            for li in sitemap_div.find_all("li", class_="List(n) Py(3px) Lh(1.2)"):
                a_tag = li.find("a", href=True)
                if a_tag and a_tag["href"].startswith("https://finance.yahoo.com/news"):
                    news_links.append(a_tag["href"])
        else:
            print(f"Could not find the sitemap content section on {current_url}")

        # Check for the "Next" link
        next_link = soup.find("a", class_="C($c-fuji-grey-k)", string="Next")
        if next_link and "href" in next_link.attrs:
            # Update the current_url to the next page
            current_url = next_link["href"]
            print(f"Moving to next page: {current_url}")
        else:
            # No "Next" link found, we've reached the final page for this date
            print(f"Finished scraping pages for date: {date}")
            break

    # Store the count for this date
    formatted_date = date.replace("_", "-")
    daily_counts[formatted_date] = len(news_links)
    total_links += len(news_links)

    # Save the links for this date to a separate JSON file
    json_file = f"data/yahoo_finance_news_{date}.json"
    with open(json_file, mode="w", encoding="utf-8") as file:
        json.dump({"date": formatted_date, "links": news_links}, file, indent=4)
    print(f"Saved {len(news_links)} links to {json_file}")

# Close the driver
driver.quit()
# Out:
# Scraping sitemap for date: 2025_01_01
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735698000000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735708163000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735721040000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735723800000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735728300000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735730408000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735733283000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735736410000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735740000000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735741020000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735742416000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735744380000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735749614000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735751416000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735756341000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735768926000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_01_start1735775727000
# Finished scraping pages for date: 2025_01_01
# Saved 831 links to data/yahoo_finance_news_2025_01_01.json
# Scraping sitemap for date: 2025_01_02
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735786810000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735794336000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735801200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735806241000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735808652000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735809480000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735811112000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735812240000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735813680000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735815211000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735815890000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735816807000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735817984000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735819200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735820220000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735821015000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735822184000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735822800000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735823700000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735824600000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735825500000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735826400000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735826700000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735827746000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735828505000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735828847000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735829700000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735830084000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735830631000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735831744000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735832799000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735833632000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735834560000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735835653000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735837020000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_02_start1735837536000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2025_01_02_start1735837536000
# Finished scraping pages for date: 2025_01_02
# Saved 1799 links to data/yahoo_finance_news_2025_01_02.json
# Scraping sitemap for date: 2025_01_03
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735869097000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735880340000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735886480000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735890187000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735894899000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735895352000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735896720000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735898045000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735899120000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735900452000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735902000000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735902780000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735903800000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735905120000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735905638000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735906536000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735907340000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735908437000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735909200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735909680000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735910460000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735911120000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735912205000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735912800000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735913116000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735914240000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735915200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735915511000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735916460000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735917959000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735918920000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735920000000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735921480000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735922657000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735923612000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735924736000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735927140000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_03_start1735929502000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2025_01_03_start1735929502000
# Finished scraping pages for date: 2025_01_03
# Saved 1895 links to data/yahoo_finance_news_2025_01_03.json
# Scraping sitemap for date: 2025_01_04
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1735973364000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1735985940000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1735992000000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1735993887000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1735996082000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1735998891000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1736002800000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1736011932000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1736025027000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_04_start1736035080000
# Finished scraping pages for date: 2025_01_04
# Saved 498 links to data/yahoo_finance_news_2025_01_04.json
# Scraping sitemap for date: 2025_01_05
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_05_start1736066700000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_05_start1736074827000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_05_start1736080200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_05_start1736084399000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_05_start1736089200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_05_start1736096533000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_05_start1736114400000
# Finished scraping pages for date: 2025_01_05
# Saved 361 links to data/yahoo_finance_news_2025_01_05.json
# Scraping sitemap for date: 2025_01_06
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736128898000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736136896000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736141135000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736146800000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736150460000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736154000000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736154600000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736156953000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736158500000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736159913000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736161200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736162296000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736163000000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736164200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_06_start1736164800000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2025_01_06_start1736164800000
# Finished scraping pages for date: 2025_01_06
# Saved 747 links to data/yahoo_finance_news_2025_01_06.json
# Scraping sitemap for date: 2025_01_07
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736210635000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736215589000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736220903000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736224200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736227671000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736233200000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736236800000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736240237000
# Moving to next page: https://finance.yahoo.com/sitemap/2025_01_07_start1736240735000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2025_01_07_start1736240735000
# Finished scraping pages for date: 2025_01_07
# Saved 449 links to data/yahoo_finance_news_2025_01_07.json

# %%
# Print the summary of daily counts
print("\nSummary of news links collected per day:")
print("Date        | Number of News Links")
print("------------|---------------------")
for date, count in daily_counts.items():
    print(f"{date} | {count}")

print(f"\nTotal news links collected: {total_links}")
# Out:
# Summary of news links collected per day:
# Date        | Number of News Links
# ------------|---------------------
# 2025-01-01 | 831
# 2025-01-02 | 1799
# 2025-01-03 | 1895
# 2025-01-04 | 498
# 2025-01-05 | 361
# 2025-01-06 | 747
# 2025-01-07 | 449
#
# Total news links collected: 6580
