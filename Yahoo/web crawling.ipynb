# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import json
from datetime import datetime, timedelta

# Setup Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run in the background
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to generate dates for January 2025
def get_january_2025_dates():
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 1, 31)
    dates = []
    current_date = start_date
    while current_date <= end_date:
        dates.append(current_date.strftime("%Y_%m_%d"))
        current_date += timedelta(days=1)
    return dates

# Dictionary to store the count of news links per day
daily_counts = {}

# Get all dates for January 2025
january_dates = get_january_2025_dates()

# Counter for total links across all days
total_links = 0

# Iterate through each date
for date in january_dates:
    print(f"Scraping sitemap for date: {date}")
    current_url = f"https://finance.yahoo.com/sitemap/{date}"

    # List to store news links for this date
    news_links = []

    while True:
        # Load the page
        driver.get(current_url)
        time.sleep(5)  # Wait for JavaScript to load

        # Get page source and parse with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Find the sitemap content div
        sitemap_div = soup.find("div", {"id": "module-sitemapcontent"})

        # Scrape news links from the current page
        if sitemap_div:
            for li in sitemap_div.find_all("li", class_="List(n) Py(3px) Lh(1.2)"):
                a_tag = li.find("a", href=True)
                if a_tag and a_tag["href"].startswith("https://finance.yahoo.com/news"):
                    news_links.append(a_tag["href"])
        else:
            print(f"Could not find the sitemap content section on {current_url}")

        # Check for the "Next" link
        next_link = soup.find("a", class_="C($c-fuji-grey-k)", string="Next")
        if next_link and "href" in next_link.attrs:
            # Update the current_url to the next page
            current_url = next_link["href"]
            print(f"Moving to next page: {current_url}")
        else:
            # No "Next" link found, we've reached the final page for this date
            print(f"Finished scraping pages for date: {date}")
            break

    # Store the count for this date
    formatted_date = date.replace("_", "-")
    daily_counts[formatted_date] = len(news_links)
    total_links += len(news_links)

    # Save the links for this date to a separate JSON file
    json_file = f"data/yahoo_finance_news_{date}.json"
    with open(json_file, mode="w", encoding="utf-8") as file:
        json.dump({"date": formatted_date, "links": news_links}, file, indent=4)
    print(f"Saved {len(news_links)} links to {json_file}")

# Close the driver
driver.quit()
# Out:
# Scraping sitemap for date: 2024_01_01
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704085290000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704099600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704105445000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704108366000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704111839000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704115800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704117660000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704120011000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704123000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704127469000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704132180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704142948000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704153390000
# Finished scraping pages for date: 2024_01_01
# Saved 643 links to data/yahoo_finance_news_2024_01_01.json
# Scraping sitemap for date: 2024_01_02
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_02
# Finished scraping pages for date: 2024_01_02
# Saved 0 links to data/yahoo_finance_news_2024_01_02.json
# Scraping sitemap for date: 2024_01_03
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704248760000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704258060000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704264830000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704268800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704272766000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704276000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704277811000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704279601000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704280620000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704281580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704283200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704284821000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704285900000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704286800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704287700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704288600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704289860000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704290400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704291060000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704292200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704293100000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704294000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704295455000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704297204000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704298200000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_03_start1704298200000
# Finished scraping pages for date: 2024_01_03
# Saved 1250 links to data/yahoo_finance_news_2024_01_03.json
# Scraping sitemap for date: 2024_01_04
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704332656000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704341683000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704348343000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704355200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704359880000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704362400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704363900000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704365940000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704366724000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704367800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704369060000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704369600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704370500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704371400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704372505000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704373200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704374489000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704375180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704376500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704376800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704377398000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704378600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704379288000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704380380000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704380820000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704382514000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704384000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704385620000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704386700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704387606000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704389280000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704391200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704394200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704397181000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704400055000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704402191000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704402900000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704405600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704407580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704408619000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704410118000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704412526000
# Finished scraping pages for date: 2024_01_04
# Saved 2091 links to data/yahoo_finance_news_2024_01_04.json
# Scraping sitemap for date: 2024_01_05
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704418860000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704426360000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704433831000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704439800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704443477000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704447598000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704449738000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704451566000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704452495000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_05_start1704453607000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_05_start1704453607000
# Finished scraping pages for date: 2024_01_05
# Saved 500 links to data/yahoo_finance_news_2024_01_05.json
# Scraping sitemap for date: 2024_01_06
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704508851000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704517140000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704535080000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704539700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704544830000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704548040000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704550860000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704557880000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_06_start1704574760000
# Finished scraping pages for date: 2024_01_06
# Saved 479 links to data/yahoo_finance_news_2024_01_06.json
# Scraping sitemap for date: 2024_01_07
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704604860000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704621600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704627900000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704631500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704635746000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704640500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704654300000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_07_start1704669128000
# Finished scraping pages for date: 2024_01_07
# Saved 412 links to data/yahoo_finance_news_2024_01_07.json
# Scraping sitemap for date: 2024_01_08
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_08_start1704682745000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_08_start1704692100000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_08_start1704696230000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_08_start1704700140000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_08_start1704704580000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_08_start1704704580000
# Finished scraping pages for date: 2024_01_08
# Saved 250 links to data/yahoo_finance_news_2024_01_08.json
# Scraping sitemap for date: 2024_01_09
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704762120000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704769860000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704777180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704782698000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704785981000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704790522000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704793320000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704794542000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704795660000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704797248000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704798020000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704799219000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704800700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704801600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704802644000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704803739000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704805200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704806477000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704807180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704808740000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704808800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704809580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704810600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704811920000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704812520000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704813900000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704815341000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704816006000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704817080000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704818557000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704819618000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704821231000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704822942000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704824359000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_09_start1704826800000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_09_start1704826800000
# Finished scraping pages for date: 2024_01_09
# Saved 1750 links to data/yahoo_finance_news_2024_01_09.json
# Scraping sitemap for date: 2024_01_10
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704851340000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704860529000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704864258000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704868200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704873299000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704877200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704879000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704880931000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704882300000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704884400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704885454000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704886740000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704888000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704889200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704890108000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704891600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704892495000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704893400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704894600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704895200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704895800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704896771000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704897605000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704898380000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704898933000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704900060000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704901140000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704902690000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704903540000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704905100000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704906539000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704908397000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704910080000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_10_start1704913161000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_10_start1704913161000
# Finished scraping pages for date: 2024_01_10
# Saved 1700 links to data/yahoo_finance_news_2024_01_10.json
# Scraping sitemap for date: 2024_01_11
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704936420000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704943125000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704949339000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704953903000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704956966000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704961213000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704964559000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704965960000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704967643000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704969300000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704970800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704971631000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704972607000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704974400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704975207000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704976200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704977753000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704978000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704979800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704980820000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704981600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704982151000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704983340000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704984011000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704984903000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704985213000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704986580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704987913000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704989367000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704990264000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704991395000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704992400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704993603000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704995107000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704996397000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1704998595000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705000320000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705003182000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705005172000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705007100000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705008274000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705010220000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705012851000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705013573000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705014919000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_11_start1705017583000
# Finished scraping pages for date: 2024_01_11
# Saved 2291 links to data/yahoo_finance_news_2024_01_11.json
# Scraping sitemap for date: 2024_01_12
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_12_start1705021506000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_12_start1705030320000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_12_start1705030320000
# Finished scraping pages for date: 2024_01_12
# Saved 100 links to data/yahoo_finance_news_2024_01_12.json
# Scraping sitemap for date: 2024_01_13
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705111354000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705126693000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705140086000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705144058000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705148400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705151700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705155938000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705165242000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_13_start1705182300000
# Finished scraping pages for date: 2024_01_13
# Saved 476 links to data/yahoo_finance_news_2024_01_13.json
# Scraping sitemap for date: 2024_01_14
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705212020000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705224684000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705231140000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705235410000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705238833000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705242420000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705248027000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705259100000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_14_start1705273222000
# Finished scraping pages for date: 2024_01_14
# Saved 465 links to data/yahoo_finance_news_2024_01_14.json
# Scraping sitemap for date: 2024_01_15
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705286684000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705297668000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705301585000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705305600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705309891000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705312680000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705313400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_15_start1705315526000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_15_start1705315526000
# Finished scraping pages for date: 2024_01_15
# Saved 400 links to data/yahoo_finance_news_2024_01_15.json
# Scraping sitemap for date: 2024_01_16
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705368600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705379700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705383541000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705388100000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705390794000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705393617000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705396380000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705399200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705400940000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705402800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705404006000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705405285000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705406400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_16_start1705407420000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_16_start1705407420000
# Finished scraping pages for date: 2024_01_16
# Saved 700 links to data/yahoo_finance_news_2024_01_16.json
# Scraping sitemap for date: 2024_01_17
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705454998000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705458877000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705467540000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705472399000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705476087000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705479300000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705482573000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705484642000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705485891000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705487226000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705489200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705490379000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705491251000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705492800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705494147000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705495026000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705496400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705497120000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705498200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705499100000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705500000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705500457000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705501597000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705502404000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705503060000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705503624000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705503767000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705505243000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705506540000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705507486000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705509000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705510380000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705511087000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_17_start1705512002000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_17_start1705512002000
# Finished scraping pages for date: 2024_01_17
# Saved 1700 links to data/yahoo_finance_news_2024_01_17.json
# Scraping sitemap for date: 2024_01_18
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_18_start1705539683000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_18_start1705546461000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_18_start1705546461000
# Finished scraping pages for date: 2024_01_18
# Saved 100 links to data/yahoo_finance_news_2024_01_18.json
# Scraping sitemap for date: 2024_01_19
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705626003000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705629733000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705636853000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705641759000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705647727000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705653121000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705656600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705658772000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705659913000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705661397000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705662126000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705663207000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705664280000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705665600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705666933000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705668300000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705669200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705670117000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705671000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_19_start1705671900000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_19_start1705671900000
# Finished scraping pages for date: 2024_01_19
# Saved 1000 links to data/yahoo_finance_news_2024_01_19.json
# Scraping sitemap for date: 2024_01_20
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705714987000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705730400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705743132000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705751400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705754524000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705757640000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705761250000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705770019000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_20_start1705784400000
# Finished scraping pages for date: 2024_01_20
# Saved 475 links to data/yahoo_finance_news_2024_01_20.json
# Scraping sitemap for date: 2024_01_21
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705817803000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705831200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705836395000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705839892000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705842745000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705846231000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705851283000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705861800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_21_start1705879098000
# Finished scraping pages for date: 2024_01_21
# Saved 459 links to data/yahoo_finance_news_2024_01_21.json
# Scraping sitemap for date: 2024_01_22
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_22_start1705886580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_22_start1705893180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_22_start1705899600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_22_start1705904536000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_22_start1705907700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_22_start1705911972000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_22_start1705914339000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_22_start1705914339000
# Finished scraping pages for date: 2024_01_22
# Saved 350 links to data/yahoo_finance_news_2024_01_22.json
# Scraping sitemap for date: 2024_01_23
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705971180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705975680000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705980827000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705985940000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705989480000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705992715000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705996080000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1705998452000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706000810000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706002980000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706004385000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706005328000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706006939000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706007720000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706008806000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706009700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706011123000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706011203000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706012077000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706013000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706014020000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706014800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706015403000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706016248000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706016660000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706017500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706018400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706019120000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706020200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706020807000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_23_start1706021405000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_23_start1706021405000
# Finished scraping pages for date: 2024_01_23
# Saved 1549 links to data/yahoo_finance_news_2024_01_23.json
# Scraping sitemap for date: 2024_01_24
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706056691000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706060580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706066685000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706071940000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706073605000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706076368000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706078880000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_24_start1706081760000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_24_start1706081760000
# Finished scraping pages for date: 2024_01_24
# Saved 400 links to data/yahoo_finance_news_2024_01_24.json
# Scraping sitemap for date: 2024_01_25
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706142609000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706146203000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706155184000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706158740000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706162854000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706165940000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706169120000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706172496000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706174460000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706175660000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706176971000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706178060000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706179152000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706180365000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706180820000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706181606000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706182500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706183734000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_25_start1706184000000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_25_start1706184000000
# Finished scraping pages for date: 2024_01_25
# Saved 950 links to data/yahoo_finance_news_2024_01_25.json
# Scraping sitemap for date: 2024_01_26
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706228760000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706230860000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706233491000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706238480000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706245140000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706249007000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706253683000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706257523000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706259840000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706261700000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_26_start1706263525000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_26_start1706263525000
# Finished scraping pages for date: 2024_01_26
# Saved 548 links to data/yahoo_finance_news_2024_01_26.json
# Scraping sitemap for date: 2024_01_27
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_27_start1706321580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_27_start1706332861000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_27_start1706332861000
# Finished scraping pages for date: 2024_01_27
# Saved 100 links to data/yahoo_finance_news_2024_01_27.json
# Scraping sitemap for date: 2024_01_28
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706421061000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706434200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706440500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706444420000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706446881000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706450400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706454180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706464800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_28_start1706478528000
# Finished scraping pages for date: 2024_01_28
# Saved 475 links to data/yahoo_finance_news_2024_01_28.json
# Scraping sitemap for date: 2024_01_29
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706488200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706494108000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706505180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706510880000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706514960000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706518800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706520929000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706522460000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706523300000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_29_start1706524468000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_29_start1706524468000
# Finished scraping pages for date: 2024_01_29
# Saved 500 links to data/yahoo_finance_news_2024_01_29.json
# Scraping sitemap for date: 2024_01_30
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706577086000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706587200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706591139000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706596378000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706601180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706603760000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706607000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706608920000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706609870000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706611071000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706612400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706613240000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706614020000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706614718000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706615820000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706616014000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706616815000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706617800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706618794000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706619600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706620063000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706621203000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_30_start1706621460000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_30_start1706621460000
# Finished scraping pages for date: 2024_01_30
# Saved 1149 links to data/yahoo_finance_news_2024_01_30.json
# Scraping sitemap for date: 2024_01_31
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706661128000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706664000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706668113000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706674996000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706677855000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706681580000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706684814000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706688877000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706691600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706693400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706695200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706695988000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706697076000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706698482000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706698813000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706699648000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706700558000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706701500000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706702400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706703302000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706704200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706705400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706706000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706706420000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706707200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706707800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706708795000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706709600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706710200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706710584000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706711400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706711880000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706712308000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_31_start1706713200000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_31_start1706713200000
# Finished scraping pages for date: 2024_01_31
# Saved 1699 links to data/yahoo_finance_news_2024_01_31.json

# %%
# Print the summary of daily counts
print("\nSummary of news links collected per day:")
print("Date        | Number of News Links")
print("------------|---------------------")
for date, count in daily_counts.items():
    print(f"{date} | {count}")

print(f"\nTotal news links collected: {total_links}")
# Out:
# Summary of news links collected per day:
# Date        | Number of News Links
# ------------|---------------------
# 2024-01-01 | 643
# 2024-01-02 | 0
# 2024-01-03 | 1250
# 2024-01-04 | 2091
# 2024-01-05 | 500
# 2024-01-06 | 479
# 2024-01-07 | 412
# 2024-01-08 | 250
# 2024-01-09 | 1750
# 2024-01-10 | 1700
# 2024-01-11 | 2291
# 2024-01-12 | 100
# 2024-01-13 | 476
# 2024-01-14 | 465
# 2024-01-15 | 400
# 2024-01-16 | 700
# 2024-01-17 | 1700
# 2024-01-18 | 100
# 2024-01-19 | 1000
# 2024-01-20 | 475
# 2024-01-21 | 459
# 2024-01-22 | 350
# 2024-01-23 | 1549
# 2024-01-24 | 400
# 2024-01-25 | 950
# 2024-01-26 | 548
# 2024-01-27 | 100
# 2024-01-28 | 475
# 2024-01-29 | 500
# 2024-01-30 | 1149
# 2024-01-31 | 1699
#
# Total news links collected: 24961

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import json
from datetime import datetime, timedelta
import random

# Setup Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run in the background
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to generate dates for January 2024
def get_january_2024_dates():
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 1, 31)
    dates = []
    current_date = start_date
    while current_date <= end_date:
        dates.append(current_date.strftime("%Y_%m_%d"))
        current_date += timedelta(days=1)
    return dates

# Dictionary to store the count of news links per day
daily_counts = {}

# Get all dates for January 2024
january_dates = get_january_2024_dates()

# Counter for total links across all days
total_links = 0

# Maximum number of links to collect per day
MAX_LINKS_PER_DAY = 100

# Iterate through each date
for date in january_dates:
    print(f"Scraping sitemap for date: {date}")
    current_url = f"https://finance.yahoo.com/sitemap/{date}"

    # Reservoir to store up to 100 randomly selected links
    reservoir = []
    # Counter for the total number of links seen
    link_count = 0

    while True:
        # Load the page
        driver.get(current_url)
        time.sleep(7)  # Wait for JavaScript to load

        # Get page source and parse with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Find the sitemap content div
        sitemap_div = soup.find("div", {"id": "module-sitemapcontent"})

        # Scrape news links from the current page
        if sitemap_div:
            for li in sitemap_div.find_all("li", class_="List(n) Py(3px) Lh(1.2)"):
                a_tag = li.find("a", href=True)
                if a_tag and a_tag["href"].startswith("https://finance.yahoo.com/news"):
                    link_count += 1

                    # Reservoir sampling
                    if len(reservoir) < MAX_LINKS_PER_DAY:
                        # If the reservoir isn't full, add the link
                        reservoir.append(a_tag["href"])
                    else:
                        # If the reservoir is full, decide whether to replace an existing link
                        # The probability of including the new link is MAX_LINKS_PER_DAY / link_count
                        if random.random() < MAX_LINKS_PER_DAY / link_count:
                            # Randomly replace an existing link in the reservoir
                            replace_index = random.randint(0, MAX_LINKS_PER_DAY - 1)
                            reservoir[replace_index] = a_tag["href"]
        else:
            print(f"Could not find the sitemap content section on {current_url}")

        # Check for the "Next" link
        next_link = soup.find("a", class_="C($c-fuji-grey-k)", string="Next")
        if next_link and "href" in next_link.attrs:
            # Update the current_url to the next page
            current_url = next_link["href"]
            print(f"Moving to next page: {current_url}")
        else:
            # No "Next" link found, we've reached the final page for this date
            print(f"Finished scraping pages for date: {date}")
            break

        # Optional: Stop early if we've seen enough links to ensure a good sample
        # If we've seen 10x the number of links we need (e.g., 1000 links for a sample of 100),
        # the reservoir is likely a good random sample, and we can stop scraping
        if link_count >= MAX_LINKS_PER_DAY * 10:
            print(f"Seen {link_count} links for {date}, stopping early for efficiency")
            break

    # The reservoir now contains up to 100 randomly selected links
    news_links = reservoir
    print(f"Collected {len(news_links)} links for {date} using reservoir sampling")

    # Store the count for this date
    formatted_date = date.replace("_", "-")
    daily_counts[formatted_date] = len(news_links)
    total_links += len(news_links)

    # Save the links for this date to a separate JSON file
    json_file = f"data/yahoo_finance_news_{date}.json"
    with open(json_file, mode="w", encoding="utf-8") as file:
        json.dump({"date": formatted_date, "links": news_links}, file, indent=4)
    print(f"Saved {len(news_links)} links to {json_file}")

# Print the summary of daily counts
print("\nSummary of news links collected per day:")
print("Date        | Number of News Links")
print("------------|---------------------")
for date, count in daily_counts.items():
    print(f"{date} | {count}")

print(f"\nTotal news links collected: {total_links}")

# Close the driver
driver.quit()
# Out:
# Scraping sitemap for date: 2024_01_01
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704085290000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704099600000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704105445000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704108366000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704111839000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704115800000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704117660000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704120011000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704123000000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704127469000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704132180000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704142948000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_01_start1704153390000
# Finished scraping pages for date: 2024_01_01
# Collected 100 links for 2024_01_01 using reservoir sampling
# Saved 100 links to data/yahoo_finance_news_2024_01_01.json
# Scraping sitemap for date: 2024_01_02
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_02_start1704165784000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_02_start1704174309000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_02_start1704180420000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_02_start1704180420000
# Finished scraping pages for date: 2024_01_02
# Collected 100 links for 2024_01_02 using reservoir sampling
# Saved 100 links to data/yahoo_finance_news_2024_01_02.json
# Scraping sitemap for date: 2024_01_03
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_03_start1704248760000
# Could not find the sitemap content section on https://finance.yahoo.com/sitemap/2024_01_03_start1704248760000
# Finished scraping pages for date: 2024_01_03
# Collected 50 links for 2024_01_03 using reservoir sampling
# Saved 50 links to data/yahoo_finance_news_2024_01_03.json
# Scraping sitemap for date: 2024_01_04
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704332656000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704341683000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704348343000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704355200000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704359880000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704362400000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704363900000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704365940000
# Moving to next page: https://finance.yahoo.com/sitemap/2024_01_04_start1704366724000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 56
#      53 while True:
#      54     # Load the page
#      55     driver.get(current_url)
# ---> 56     time.sleep(7)  # Wait for JavaScript to load
#      58     # Get page source and parse with BeautifulSoup
#      59     soup = BeautifulSoup(driver.page_source, "html.parser")
#
# KeyboardInterrupt:
