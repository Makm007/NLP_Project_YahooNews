# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import json
import csv
from datetime import datetime, timedelta
import os

# Setup Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run in the background
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Initialize WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Function to generate dates for January 2025
def get_january_2025_dates():
    start_date = datetime(2024, 1, 1)
    end_date = datetime(2024, 1, 3)
    dates = []
    current_date = start_date
    while current_date <= end_date:
        dates.append(current_date.strftime("%Y_%m_%d"))
        current_date += timedelta(days=1)
    return dates

# Dictionary to store the count of news links per day
daily_counts = {}

# Get all dates for January 2025
january_dates = get_january_2025_dates()

# Counter for total links across all days
total_links = 0

# Path to the 'data' folder where JSON files are stored
data_folder = "data"

# Iterate through each date
for date in january_dates:
    print(f"Processing date: {date}")

    # Construct the path to the JSON file
    json_file = os.path.join(data_folder, f"yahoo_finance_news_{date}.json")
    try:
        with open(json_file, mode="r", encoding="utf-8") as file:
            data = json.load(file)
            news_links = data["links"]
            formatted_date = data["date"]
    except FileNotFoundError:
        print(f"JSON file for {date} not found in {data_folder}. Skipping...")
        daily_counts[date.replace("_", "-")] = 0
        continue

    # Store the count for this date
    daily_counts[formatted_date] = len(news_links)
    total_links += len(news_links)

    # List to store news articles for this date
    news_articles = []

    # Scrape the content of each news link
    for link in news_links:
        print(f"Scraping article: {link}")
        driver.get(link)
        time.sleep(3)  # Wait for JavaScript to load

        # Get page source and parse with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, "html.parser")

        # Find the article body
        article_body = soup.find("div", class_="body yf-lk6bwk")
        if article_body:
            # Extract text from all <p> tags within the article body
            paragraphs = article_body.find_all("p")
            article_text = " ".join(p.get_text(strip=True) for p in paragraphs)
        else:
            article_text = "Article body not found"

        # Add the article data to the list
        news_articles.append((formatted_date, link, article_text))

    # Save the news articles for this date to a separate CSV file
    csv_file = f"yahoo_finance_news_content_{date}.csv"
    with open(csv_file, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(["Date", "Link", "Content"])
        # Write the data
        for article in news_articles:
            writer.writerow(article)
    print(f"Saved {len(news_articles)} articles to {csv_file}")

# Print the summary of daily counts
print("\nSummary of news links processed per day:")
print("Date        | Number of News Links")
print("------------|---------------------")
for date, count in daily_counts.items():
    print(f"{date} | {count}")

print(f"\nTotal news links processed: {total_links}")

# Close the driver
driver.quit()
# Out:
# Processing date: 2024_01_01
# Scraping article: https://finance.yahoo.com/news/delta-air-lines-nyse-dal-155125769.html
# Scraping article: https://finance.yahoo.com/news/workers-england-states-look-forward-100842915.html
# Scraping article: https://finance.yahoo.com/news/diversified-united-investment-insider-ups-001635743.html
# Scraping article: https://finance.yahoo.com/news/intrinsic-calculation-amazon-com-inc-120020526.html
# Scraping article: https://finance.yahoo.com/news/4-reasons-ionq-stock-could-165300624.html
# Scraping article: https://finance.yahoo.com/news/1-russia-declares-tsunami-warnings-092541954.html
# Scraping article: https://finance.yahoo.com/news/insiders-au-898-9k-investments-213103680.html
# Scraping article: https://finance.yahoo.com/news/history-says-nasdaq-surge-2024-142000237.html
# Scraping article: https://finance.yahoo.com/news/investors-heavily-search-cocacola-company-140011220.html
# Scraping article: https://finance.yahoo.com/news/osisko-development-corp-cve-odv-165351838.html
# Scraping article: https://finance.yahoo.com/news/ally-financial-stock-buy-114500673.html
# Scraping article: https://finance.yahoo.com/news/1-least-five-dead-huge-232015222.html
# Scraping article: https://finance.yahoo.com/news/calculating-fair-value-duopharma-biotech-011518072.html
# Scraping article: https://finance.yahoo.com/news/pdvyx-strong-bond-fund-now-120004152.html
# Scraping article: https://finance.yahoo.com/news/1-australias-eagers-automotive-finds-224242948.html
# Scraping article: https://finance.yahoo.com/news/investors-consolidated-edison-nyse-ed-150400335.html
# Scraping article: https://finance.yahoo.com/news/heres-why-united-therapeutics-uthr-144506795.html
# Scraping article: https://finance.yahoo.com/news/makes-honeywell-international-inc-hon-170005218.html
# Scraping article: https://finance.yahoo.com/news/worst-investment-idea-2024-buying-194646692.html
# Scraping article: https://finance.yahoo.com/news/3-top-dividend-stocks-maximize-141003618.html
# Scraping article: https://finance.yahoo.com/news/li-auto-inc-december-2023-020000306.html
# Scraping article: https://finance.yahoo.com/news/liberty-siriusxm-groups-nasdaq-lsxm-105929200.html
# Scraping article: https://finance.yahoo.com/news/analysts-optimistic-well-see-profit-130805000.html
# Scraping article: https://finance.yahoo.com/news/u-cities-where-cheapest-own-150015759.html
# Scraping article: https://finance.yahoo.com/news/crexendo-inc-nasdaq-cxdo-insiders-180235018.html
# Scraping article: https://finance.yahoo.com/news/housing-market-3-most-expensive-150024737.html
# Scraping article: https://finance.yahoo.com/news/3-top-ranked-mutual-funds-130003005.html
# Scraping article: https://finance.yahoo.com/news/1-warren-buffett-stock-down-140000572.html
# Scraping article: https://finance.yahoo.com/news/past-three-years-general-motors-131446791.html
# Scraping article: https://finance.yahoo.com/news/housing-market-predictions-six-experts-135838200.html
# Scraping article: https://finance.yahoo.com/news/top-experts-biggest-predictions-us-213101575.html
# Scraping article: https://finance.yahoo.com/news/ukraines-zelenskiy-says-russia-suffering-203552998.html
# Scraping article: https://finance.yahoo.com/news/now-opportunity-globetronics-technology-bhd-030533357.html
# Scraping article: https://finance.yahoo.com/news/investing-preview-2024-buy-4-132100193.html
# Scraping article: https://finance.yahoo.com/news/minimum-wage-tolls-health-care-120000287.html
# Scraping article: https://finance.yahoo.com/news/capital-allocation-trends-sats-sgx-041110850.html
# Scraping article: https://finance.yahoo.com/news/bintulu-port-holdings-berhads-klse-042124375.html
# Scraping article: https://finance.yahoo.com/news/joyy-announces-latest-development-sale-130200351.html
# Scraping article: https://finance.yahoo.com/news/9-economic-trends-to-watch-in-2024-185519805.html
# Scraping article: https://finance.yahoo.com/news/brokers-suggest-investing-palo-alto-143005563.html
# Scraping article: https://finance.yahoo.com/news/docusign-inc-nasdaq-docu-impressive-125701663.html
# Scraping article: https://finance.yahoo.com/news/2-computer-technology-stocks-could-140006736.html
# Scraping article: https://finance.yahoo.com/news/investors-lose-7bn-british-banks-152648831.html
# Scraping article: https://finance.yahoo.com/news/jeremy-grantham-rang-alarm-everything-193501484.html
# Scraping article: https://finance.yahoo.com/news/inbound-medical-tourism-market-reach-123000610.html
# Scraping article: https://finance.yahoo.com/news/3-best-womens-clothing-stores-101001824.html
# Scraping article: https://finance.yahoo.com/news/automated-fare-collection-afc-system-210000189.html
# Scraping article: https://finance.yahoo.com/news/first-trust-small-cap-core-112007226.html
# Scraping article: https://finance.yahoo.com/news/mini-series-sparked-gold-rush-093000501.html
# Scraping article: https://finance.yahoo.com/news/consolidated-water-co-ltd-nasdaq-101721997.html
# Scraping article: https://finance.yahoo.com/news/interventional-cardiology-devices-market-size-170000966.html
# Scraping article: https://finance.yahoo.com/news/pharos-energy-plcs-lon-phar-050447883.html
# Scraping article: https://finance.yahoo.com/news/invest-invesco-p-500-equal-112005913.html
# Scraping article: https://finance.yahoo.com/news/intrinsic-calculation-jenoptik-ag-etr-094849090.html
# Scraping article: https://finance.yahoo.com/news/heres-why-walmart-wmt-strong-145008743.html
# Scraping article: https://finance.yahoo.com/news/airsculpt-technologies-airs-outperforming-other-144009777.html
# Scraping article: https://finance.yahoo.com/news/maersk-pauses-shipping-red-sea-103725295.html
# Scraping article: https://finance.yahoo.com/news/natures-remedy-cannabis-nrc-unveils-150000987.html
# Scraping article: https://finance.yahoo.com/news/why-1-momentum-stock-could-145007239.html
# Scraping article: https://finance.yahoo.com/news/patterson-companies-inc-nasdaq-pdco-123911166.html
# Scraping article: https://finance.yahoo.com/news/physical-vapor-deposition-market-size-151400997.html
# Scraping article: https://finance.yahoo.com/news/invested-1000-dycom-industries-decade-133004846.html
# Scraping article: https://finance.yahoo.com/news/flash-news-okx-wallet-now-093000698.html
# Scraping article: https://finance.yahoo.com/news/regional-ag-conference-scheduled-delhi-233600424.html
# Scraping article: https://finance.yahoo.com/news/sodium-phosphate-market-size-worth-151800919.html
# Scraping article: https://finance.yahoo.com/news/fast-paced-momentum-stock-dream-135006800.html
# Scraping article: https://finance.yahoo.com/news/haemato-ags-etr-haek-intrinsic-060236187.html
# Scraping article: https://finance.yahoo.com/news/intra-cellular-therapies-itci-now-145505102.html
# Scraping article: https://finance.yahoo.com/news/heres-why-sanofi-sny-strong-144007522.html
# Scraping article: https://finance.yahoo.com/news/gainesville-based-wound-care-business-175756396.html
# Scraping article: https://finance.yahoo.com/news/3-hottest-telehealth-stocks-watch-203134924.html
# Scraping article: https://finance.yahoo.com/news/financials-role-play-driving-doubleverify-115026636.html
# Scraping article: https://finance.yahoo.com/news/bank-koreas-rhee-eyes-warning-062754717.html
# Scraping article: https://finance.yahoo.com/news/medical-seo-marketing-revolutionizing-patient-062900732.html
# Scraping article: https://finance.yahoo.com/news/newswire-smart-start-guide-shares-150000015.html
# Scraping article: https://finance.yahoo.com/news/mixed-fundamentals-negative-impact-kraft-113244564.html
# Scraping article: https://finance.yahoo.com/news/competitive-pay-tsmc-plant-may-093000561.html
# Scraping article: https://finance.yahoo.com/news/77-ownership-priority-technology-holdings-140610806.html
# Scraping article: https://finance.yahoo.com/news/olympia-financial-group-inc-announces-100000261.html
# Scraping article: https://finance.yahoo.com/news/1-bank-israel-cuts-rate-153851491.html
# Scraping article: https://finance.yahoo.com/news/time-sell-shiba-inu-121300464.html
# Scraping article: https://finance.yahoo.com/news/jobs-saw-biggest-pay-hikes-155826350.html
# Scraping article: https://finance.yahoo.com/news/heres-much-youd-invested-1000-133004663.html
# Scraping article: https://finance.yahoo.com/news/patrick-industries-nasdaq-patk-could-114134809.html
# Scraping article: https://finance.yahoo.com/news/des-moines-favorite-lacheles-fine-120329143.html
# Scraping article: https://finance.yahoo.com/news/skip-10-home-renovations-going-220047518.html
# Scraping article: https://finance.yahoo.com/news/fitness-app-market-size-worth-152300544.html
# Scraping article: https://finance.yahoo.com/news/got-5-000-2-best-123000401.html
# Scraping article: https://finance.yahoo.com/news/mhp-lon-mhpc-way-become-074719821.html
# Scraping article: https://finance.yahoo.com/news/dave-ramsey-4-things-build-140015934.html
# Scraping article: https://finance.yahoo.com/news/average-investors-financial-shenanigans-tough-224509177.html
# Scraping article: https://finance.yahoo.com/news/tate-lyle-plcs-lon-tate-080217765.html
# Scraping article: https://finance.yahoo.com/news/colony-bankcorp-nasdaq-cban-ticks-104358610.html
# Scraping article: https://finance.yahoo.com/news/israels-p-cure-looks-expand-093000587.html
# Scraping article: https://finance.yahoo.com/news/eagle-materials-exp-great-value-144011502.html
# Scraping article: https://finance.yahoo.com/news/esco-technologies-ese-incredible-growth-174503933.html
# Scraping article: https://finance.yahoo.com/news/3-reasons-buy-teladoc-stock-134500136.html
# Scraping article: https://finance.yahoo.com/news/know-senestech-inc-snes-rating-170005782.html
# Scraping article: https://finance.yahoo.com/news/j-b-hunt-transport-services-130338808.html
# Scraping article: https://finance.yahoo.com/news/flash-news-okx-wallet-now-090000013.html
# Saved 100 articles to yahoo_finance_news_content_2024_01_01.csv
# Processing date: 2024_01_02
# Scraping article: https://finance.yahoo.com/news/8-best-clothing-deals-costco-000028899.html
# Scraping article: https://finance.yahoo.com/news/wise-art-ag-subsidiary-wisekey-060000575.html
# Scraping article: https://finance.yahoo.com/news/caledonia-mining-corporation-plc-caledonia-070000129.html
# Scraping article: https://finance.yahoo.com/news/vgp-nv-voting-rights-denominator-060000363.html
# Scraping article: https://finance.yahoo.com/news/wesfarmers-asx-wes-earnings-warrant-001312955.html
# Scraping article: https://finance.yahoo.com/news/cognitive-supply-chain-market-expected-003000072.html
# Scraping article: https://finance.yahoo.com/news/efe-introduces-fresh-reading-glasses-003000259.html
# Scraping article: https://finance.yahoo.com/news/thxnet-concludes-hackathon-japan-smbc-062200467.html
# Scraping article: https://finance.yahoo.com/news/train-derails-catches-fire-near-003126194.html
# Scraping article: https://finance.yahoo.com/news/maersk-decide-red-sea-route-062209202.html
# Scraping article: https://finance.yahoo.com/news/1-netherlands-blocks-asml-exports-003526633.html
# Scraping article: https://finance.yahoo.com/news/sidney-wolfe-longtime-us-consumer-003549131.html
# Scraping article: https://finance.yahoo.com/news/proposed-solar-facility-south-santa-003600089.html
# Scraping article: https://finance.yahoo.com/news/too-consider-buying-coastal-contracts-004237983.html
# Scraping article: https://finance.yahoo.com/news/private-companies-account-59-oriental-005719217.html
# Scraping article: https://finance.yahoo.com/news/maersk-continues-schedule-suez-journeys-061954371.html
# Scraping article: https://finance.yahoo.com/news/mustafa-suleyman-wants-balance-ai-070000959.html
# Scraping article: https://finance.yahoo.com/news/1-sidney-wolfe-longtime-us-010437744.html
# Scraping article: https://finance.yahoo.com/news/owning-45-cape-ems-berhad-010440112.html
# Scraping article: https://finance.yahoo.com/news/press-digest-british-business-jan-010800416.html
# Scraping article: https://finance.yahoo.com/news/bp-plastics-holding-bhd-klse-011204055.html
# Scraping article: https://finance.yahoo.com/news/eco-atlantic-oil-gas-ltd-070000770.html
# Scraping article: https://finance.yahoo.com/news/zealand-pharma-participate-goldman-sachs-070000528.html
# Scraping article: https://finance.yahoo.com/news/dollar-starts-2024-steady-focus-012359938.html
# Scraping article: https://finance.yahoo.com/news/investors-undervaluing-malayan-cement-berhad-013405774.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 70
#      68 for link in news_links:
#      69     print(f"Scraping article: {link}")
# ---> 70     driver.get(link)
#      71     time.sleep(3)  # Wait for JavaScript to load
#      73     # Get page source and parse with BeautifulSoup
#
# File c:\Users\markham\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """Navigate the browser to the specified URL in the current window or
#     438     tab.
#     439
#    (...)
#     452     >>> driver.get("https://example.com")
#     453     """
# --> 454     self.execute(Command.GET, {"url": url})
#
# File c:\Users\markham\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:427, in WebDriver.execute(self, driver_command, params)
#     424     elif "sessionId" not in params:
#     425         params["sessionId"] = self.session_id
# --> 427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
#     429     self.error_handler.check_response(response)
#
# File c:\Users\markham\anaconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File c:\Users\markham\anaconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File c:\Users\markham\anaconda3\Lib\site-packages\urllib3\request.py:81, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      77     return self.request_encode_url(
#      78         method, url, fields=fields, headers=headers, **urlopen_kw
#      79     )
#      80 else:
# ---> 81     return self.request_encode_body(
#      82         method, url, fields=fields, headers=headers, **urlopen_kw
#      83     )
#
# File c:\Users\markham\anaconda3\Lib\site-packages\urllib3\request.py:173, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     170 extra_kw["headers"].update(headers)
#     171 extra_kw.update(urlopen_kw)
# --> 173 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\markham\anaconda3\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File c:\Users\markham\anaconda3\Lib\site-packages\urllib3\connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File c:\Users\markham\anaconda3\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\markham\anaconda3\Lib\site-packages\urllib3\connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File c:\Users\markham\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\markham\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\markham\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\markham\anaconda3\Lib\socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# KeyboardInterrupt:
